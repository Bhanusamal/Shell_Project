# %%
import streamlit as st
import pandas as pd
import numpy as np
import joblib
from sklearn.cluster import KMeans

# %%
# Load saved models and data
selected_features = joblib.load("selected_features.pkl")
pca = joblib.load("pca_model.pkl")
historical_df = pd.read_csv("pca_transformed.csv")

# %%
import streamlit as st
import pandas as pd
import numpy as np
import joblib
from sklearn.cluster import KMeans  # Only if you're adding clustering

# Load saved models
selected_features = joblib.load("selected_features.pkl")
pca = joblib.load("pca_model.pkl")

st.title("🌍 Climate Feature Explorer")
st.markdown("Project environmental data into PCA space to explore patterns and trends.")

st.sidebar.header("Enter Environmental Data")
user_input = {}
for feature in selected_features:
    user_input[feature] = st.sidebar.number_input(f"{feature}", value=0.0)

input_df = pd.DataFrame([user_input])
input_df.fillna(0, inplace=True)

if st.button("Project into PCA Space"):
    projection = pca.transform(input_df)
    st.success("✅ Projection complete!")
    st.write("📍 PCA Coordinates:", {f"PC{i+1}": round(val, 4) for i, val in enumerate(projection[0])})

    # Optional: Load historical PCA data
    try:
        historical_df = pd.read_csv("pca_transformed.csv")
        historical_df.columns = [f"PC{i+1}" for i in range(historical_df.shape[1])]
        user_point = pd.DataFrame(projection, columns=historical_df.columns)
        combined = pd.concat([historical_df, user_point], ignore_index=True)

        st.subheader("📊 PCA Projection with Historical Context")
        st.scatter_chart(combined.iloc[:, :2])  # PC1 vs PC2

        # Optional clustering
        kmeans = KMeans(n_clusters=3, random_state=42)
        clusters = kmeans.fit_predict(historical_df)
        user_cluster = kmeans.predict(user_point)[0]
        st.info(f"🧭 Your input falls into Cluster {user_cluster}")

    except FileNotFoundError:
        st.warning("No historical PCA data found. Upload 'pca_transformed.csv' to enable comparison.")
# Out:
# 2025-09-15 22:49:28.523 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.959
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\bhanu\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-09-15 22:49:28.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.963 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.972 Session state does not function when running a script without `streamlit run`
# 2025-09-15 22:49:28.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.976 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.989 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.997 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.998 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:28.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.003 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.010 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.013 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.014 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.015 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.016 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-15 22:49:29.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
